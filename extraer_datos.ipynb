# %% [markdown]
# # Este código sirve para crear una serie de carpetas que contienen los archivos de texto originales
#
# Solo agrupa los archivos originales en unas carpetas nuevas.

# %%
import pandas as pd
import numpy as np
import os
import re
import matplotlib.pyplot as plt

# %%
path = '/home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/Entrenamiento/red-1/Ax+/Acts/10(mot,cr)'
df = pd.read_csv(path, header =None)
df.head()
# Out:
#           0
# 0  0.006032
# 1  0.006209
# 2  0.006301
# 3  0.006348
# 4  0.006411

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       200 non-null    float64
# dtypes: float64(1)
# memory usage: 1.7 KB

# %%
df = pd.DataFrame(df) 
df.columns=['Act R1'] 
df.head()
# Out:
#     Act R11
# 0  0.006032
# 1  0.006209
# 2  0.006301
# 3  0.006348
# 4  0.006411

# %%
x = np.arange(.99, 200)
plt.errorbar(x, df, color = 'K', label=r'$Red-1$')
plt.legend(fontsize = 15)
plt.show()

# %%
#creamos las variables que contienen a la carpeta origen y a la nueva para los datos de entrenamiento
ubicacion_original = "/home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/"
ubicacion_nueva = "/home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/" + "datos_filtrados_entrenamiento"

if os.path.exists(ubicacion_nueva):
    os.path.exists(ubicacion_original)
else:
    os.mkdir(ubicacion_nueva)

# %%
ruta = ubicacion_original
archivo_nuevo = ubicacion_nueva + '/'
datos_TOTAL = pd.DataFrame()

def sorted_aphanumeric(contenido):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(contenido, key=alphanum_key)

#se obtiene una lista desordenada con todos los 
#archivos que están en la ubicación original
contenido = sorted_aphanumeric(os.listdir(ruta))

for elemento in contenido:
    archivo_original = ruta + elemento + '/simulation data/Entrenamiento/'
    #print('elemento', archivo_original)
    contenido_entrenamiento = sorted_aphanumeric(os.listdir(archivo_original))
   # print(contenido_entrenamiento)
    
    carpeta_nueva = ubicacion_nueva + '/' + elemento
    #creamos la nueva carpeta
    if os.path.exists(carpeta_nueva):
        os.path.exists(ubicacion_original)
    else:
        os.mkdir(carpeta_nueva)
    
    for i in contenido_entrenamiento:
        archivo =  archivo_original + i + '/Ax+/Acts/10(mot,cr)'
        print(archivo)
        datos = pd.read_csv(archivo, sep = ': ', engine='python', keep_default_na=False,
                na_values=[' '])
        
        datos_TOTAL = pd.DataFrame(datos)
        datos_TOTAL.columns=[i]
        
        archivo_nuevo = carpeta_nueva + '/' + i
        file = open(archivo_nuevo, "w")
        for valor in datos_TOTAL[i]:
            a = str(valor)
            file.write(a + os.linesep)
    
        file.close()
# Out:
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/Entrenamiento/red-1/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/Entrenamiento/red-2/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/Entrenamiento/red-3/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/Entrenamiento/red-4/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/Entrenamiento/red-5/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/Entrenamiento/red-6/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/Entrenamiento/red-7/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/Entrenamiento/red-8/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/Entrenamiento/red-9/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/Entrenamiento/red-10/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/Entrenamiento/red-1/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/Entrenamiento/red-2/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/Entrenamiento/red-3/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/Entrenamiento/red-4/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/Entrenamiento/red-5/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/Entrenamiento/red-6/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/Entrenamiento/red-7/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/Entrenamiento/red-8/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/Entrenamiento/red-9/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/Entrenamiento/red-10/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/Entrenamiento/red-1/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/Entrenamiento/red-2/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/Entrenamiento/red-3/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/Entrenamiento/red-4/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/Entrenamiento/red-5/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/Entrenamiento/red-6/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/Entrenamiento/red-7/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/Entrenamiento/red-8/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/Entrenamiento/red-9/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/Entrenamiento/red-10/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/Entrenamiento/red-1/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/Entrenamiento/red-2/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/Entrenamiento/red-3/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/Entrenamiento/red-4/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/Entrenamiento/red-5/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/Entrenamiento/red-6/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/Entrenamiento/red-7/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/Entrenamiento/red-8/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/Entrenamiento/red-9/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/Entrenamiento/red-10/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/Entrenamiento/red-1/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/Entrenamiento/red-2/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/Entrenamiento/red-3/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/Entrenamiento/red-4/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/Entrenamiento/red-5/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/Entrenamiento/red-6/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/Entrenamiento/red-7/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/Entrenamiento/red-8/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/Entrenamiento/red-9/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/Entrenamiento/red-10/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/Entrenamiento/red-1/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/Entrenamiento/red-2/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/Entrenamiento/red-3/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/Entrenamiento/red-4/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/Entrenamiento/red-5/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/Entrenamiento/red-6/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/Entrenamiento/red-7/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/Entrenamiento/red-8/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/Entrenamiento/red-9/Ax+/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/Entrenamiento/red-10/Ax+/Acts/10(mot,cr)

# %%
#creamos las variables que contienen a la carpeta origen y a la nueva para los datos de pruebas A
ubicacion_original = "/home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/"
ubicacion_nueva = "/home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/" + "datos_filtrados_pruebas_A"

if os.path.exists(ubicacion_nueva):
    os.path.exists(ubicacion_original)
else:
    os.mkdir(ubicacion_nueva)

# %%
ruta = ubicacion_original
archivo_nuevo = ubicacion_nueva + '/'
datos_TOTAL = pd.DataFrame()

def sorted_aphanumeric(contenido):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(contenido, key=alphanum_key)

contenido = sorted_aphanumeric(os.listdir(ruta))

for elemento in contenido:
    archivo_original = ruta + elemento + '/simulation data/A-/'
    #print('elemento', archivo_original)
    contenido_entrenamiento = sorted_aphanumeric(os.listdir(archivo_original))
   # print(contenido_entrenamiento)
    
    carpeta_nueva = ubicacion_nueva + '/' + elemento
    #creamos la nueva carpeta
    if os.path.exists(carpeta_nueva):
        os.path.exists(ubicacion_original)
    else:
        os.mkdir(carpeta_nueva)
    
    for i in contenido_entrenamiento:
        archivo =  archivo_original + i + '/A-/Acts/10(mot,cr)'
        print(archivo)
        datos = pd.read_csv(archivo, sep = ': ', engine='python', keep_default_na=False,
                na_values=[' '])
        
        datos_TOTAL = pd.DataFrame(datos)
        datos_TOTAL.columns=[i]
        
        archivo_nuevo = carpeta_nueva + '/' + i
        file = open(archivo_nuevo, "w")
        for valor in datos_TOTAL[i]:
            a = str(valor)
            file.write(a + os.linesep)
    
        file.close()
# Out:
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/A-/red-1/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/A-/red-2/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/A-/red-3/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/A-/red-4/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/A-/red-5/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/A-/red-6/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/A-/red-7/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/A-/red-8/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/A-/red-9/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/A-/red-10/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/A-/red-1/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/A-/red-2/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/A-/red-3/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/A-/red-4/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/A-/red-5/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/A-/red-6/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/A-/red-7/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/A-/red-8/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/A-/red-9/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/A-/red-10/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/A-/red-1/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/A-/red-2/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/A-/red-3/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/A-/red-4/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/A-/red-5/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/A-/red-6/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/A-/red-7/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/A-/red-8/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/A-/red-9/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/A-/red-10/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/A-/red-1/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/A-/red-2/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/A-/red-3/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/A-/red-4/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/A-/red-5/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/A-/red-6/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/A-/red-7/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/A-/red-8/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/A-/red-9/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/A-/red-10/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/A-/red-1/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/A-/red-2/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/A-/red-3/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/A-/red-4/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/A-/red-5/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/A-/red-6/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/A-/red-7/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/A-/red-8/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/A-/red-9/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/A-/red-10/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/A-/red-1/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/A-/red-2/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/A-/red-3/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/A-/red-4/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/A-/red-5/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/A-/red-6/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/A-/red-7/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/A-/red-8/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/A-/red-9/A-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/A-/red-10/A-/Acts/10(mot,cr)

# %%
#creamos las variables que contienen a la carpeta origen y a la nueva para los datos de pruebas x
ubicacion_original = "/home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/"
ubicacion_nueva = "/home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/" + "datos_filtrados_pruebas_x"

if os.path.exists(ubicacion_nueva):
    os.path.exists(ubicacion_original)
else:
    os.mkdir(ubicacion_nueva)

# %%
ruta = ubicacion_original
archivo_nuevo = ubicacion_nueva + '/'
datos_TOTAL = pd.DataFrame()

def sorted_aphanumeric(contenido):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(contenido, key=alphanum_key)

contenido = sorted_aphanumeric(os.listdir(ruta))

for elemento in contenido:
    archivo_original = ruta + elemento + '/simulation data/x-/'
    #print('elemento', archivo_original)
    contenido_entrenamiento = sorted_aphanumeric(os.listdir(archivo_original))
   # print(contenido_entrenamiento)
    
    carpeta_nueva = ubicacion_nueva + '/' + elemento
    #creamos la nueva carpeta
    if os.path.exists(carpeta_nueva):
        os.path.exists(ubicacion_original)
    else:
        os.mkdir(carpeta_nueva)
    
    for i in contenido_entrenamiento:
        archivo =  archivo_original + i + '/x-/Acts/10(mot,cr)'
        print(archivo)
        datos = pd.read_csv(archivo, sep = ': ', engine='python', keep_default_na=False,
                na_values=[' '])
        
        datos_TOTAL = pd.DataFrame(datos)
        datos_TOTAL.columns=[i]
        
        archivo_nuevo = carpeta_nueva + '/' + i
        file = open(archivo_nuevo, "w")
        for valor in datos_TOTAL[i]:
            a = str(valor)
            file.write(a + os.linesep)
    
        file.close()
# Out:
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/x-/red-1/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/x-/red-2/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/x-/red-3/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/x-/red-4/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/x-/red-5/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/x-/red-6/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/x-/red-7/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/x-/red-8/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/x-/red-9/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/x-/red-10/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/x-/red-1/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/x-/red-2/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/x-/red-3/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/x-/red-4/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/x-/red-5/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/x-/red-6/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/x-/red-7/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/x-/red-8/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/x-/red-9/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(1)x/simulation data/x-/red-10/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/x-/red-1/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/x-/red-2/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/x-/red-3/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/x-/red-4/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/x-/red-5/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/x-/red-6/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/x-/red-7/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/x-/red-8/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/x-/red-9/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(2)x/simulation data/x-/red-10/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/x-/red-1/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/x-/red-2/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/x-/red-3/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/x-/red-4/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/x-/red-5/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/x-/red-6/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/x-/red-7/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/x-/red-8/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/x-/red-9/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A(4)x/simulation data/x-/red-10/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/x-/red-1/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/x-/red-2/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/x-/red-3/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/x-/red-4/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/x-/red-5/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/x-/red-6/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/x-/red-7/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/x-/red-8/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/x-/red-9/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/Ax/simulation data/x-/red-10/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/x-/red-1/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/x-/red-2/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/x-/red-3/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/x-/red-4/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/x-/red-5/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/x-/red-6/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/x-/red-7/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/x-/red-8/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/x-/red-9/x-/Acts/10(mot,cr)
# /home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/x/simulation data/x-/red-10/x-/Acts/10(mot,cr)
