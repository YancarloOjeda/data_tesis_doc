# %% [markdown]
# # Este código sirve para crear una serie de carpetas que contienen los archivos de texto originales
#
# Solo agrupa los archivos originales en carpetas nuevas. Los archivos son los .txt de las activaciones de las redes de mi experimento de tesis doctoral.

# %%
import pandas as pd
import numpy as np
import os
import re
import matplotlib.pyplot as plt

# %%
#Linux
#path = '/home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/A/simulation data/Entrenamiento/red-1/Ax+/Acts/10(mot,cr)'
#Windows
path = 'C:/Users/yanoj/OneDrive/Documentos/simulacion/datos/Ax/simulacion data/Ax/2-2(2)-2(1)-1-1/Ax/Acts/10(mot,cr)'
df = pd.read_csv(path, header =None)
df.head()
# Out:
#           0
# 0  0.006031
# 1  0.006209
# 2  0.006301
# 3  0.006348
# 4  0.006371

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       300 non-null    float64
# dtypes: float64(1)
# memory usage: 2.5 KB

# %%
df = pd.DataFrame(df) 
df.columns=['Act R1'] 
df.head()
# Out:
#      Act R1
# 0  0.006031
# 1  0.006209
# 2  0.006301
# 3  0.006348
# 4  0.006371

# %%
x = np.arange(.99, 300)
plt.errorbar(x, df, color = 'K', label=r'$Red-1$')
plt.legend(fontsize = 15)
plt.show()
# Out:
# C:\Users\yanoj\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: MatplotlibDeprecationWarning: Support for uppercase single-letter colors is deprecated since Matplotlib 3.1 and will be removed in 3.3; please use lowercase instead.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
#creamos las variables que contienen a la carpeta origen y a la nueva para los datos de entrenamiento
#Linux
#ubicacion_original = "/home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/"
#ubicacion_nueva = "/home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/" + "datos_filtrados_entrenamiento"

#Windows--- VERIFICAR RUTA
ubicacion_original = 'C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/'
ubicacion_nueva = 'C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/'+"datos_filtrados_entrenamiento"

if os.path.exists(ubicacion_nueva):
    os.path.exists(ubicacion_original)
else:
    os.mkdir(ubicacion_nueva)

# %%
ruta = ubicacion_original
archivo_nuevo = ubicacion_nueva + '/'
datos_TOTAL = pd.DataFrame()

def sorted_aphanumeric(contenido):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(contenido, key=alphanum_key)

#se obtiene una lista desordenada con todos los 
#archivos que están en la ubicación original
contenido = sorted_aphanumeric(os.listdir(ruta))

for elemento in contenido:
    #Linux
    #archivo_original = ruta + elemento + '/simulation data/Entrenamiento/'
    #Windows
    archivo_original = ruta + elemento + '/simulacion data/Ax/'
    #print(elemento)
    #print('elemento', archivo_original)
    contenido_entrenamiento = sorted_aphanumeric(os.listdir(archivo_original))
    #print(contenido_entrenamiento)
    
    carpeta_nueva = ubicacion_nueva + '/' + elemento
    #creamos la nueva carpeta
    if os.path.exists(carpeta_nueva):
        os.path.exists(ubicacion_original)
    else:
        os.mkdir(carpeta_nueva)
    
    for i in contenido_entrenamiento:
        archivo =  archivo_original + i + '/Ax/Acts/11(mot,cr)'#VERIFICAR UNIDAD
        print(archivo)
        datos = pd.read_csv(archivo, sep = ': ', engine='python', keep_default_na=False,
                na_values=[' '])
        
        datos_TOTAL = pd.DataFrame(datos)
        datos_TOTAL.columns=[i]
        
        archivo_nuevo = carpeta_nueva + '/' + i
        file = open(archivo_nuevo, "w")
        for valor in datos_TOTAL[i]:
            a = str(valor)
            file.write(a + os.linesep)
    
        file.close()
# Out:
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/Ax/red-1/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/Ax/red-2/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/Ax/red-3/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/Ax/red-4/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/Ax/red-5/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/Ax/red-6/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/Ax/red-7/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/Ax/red-8/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/Ax/red-9/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/Ax/red-10/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/Ax/red-1/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/Ax/red-2/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/Ax/red-3/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/Ax/red-4/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/Ax/red-5/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/Ax/red-6/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/Ax/red-7/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/Ax/red-8/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/Ax/red-9/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/Ax/red-10/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/Ax/red-1/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/Ax/red-2/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/Ax/red-3/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/Ax/red-4/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/Ax/red-5/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/Ax/red-6/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/Ax/red-7/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/Ax/red-8/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/Ax/red-9/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/Ax/red-10/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/Ax/red-1/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/Ax/red-2/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/Ax/red-3/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/Ax/red-4/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/Ax/red-5/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/Ax/red-6/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/Ax/red-7/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/Ax/red-8/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/Ax/red-9/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/Ax/red-10/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/Ax/red-1/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/Ax/red-2/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/Ax/red-3/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/Ax/red-4/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/Ax/red-5/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/Ax/red-6/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/Ax/red-7/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/Ax/red-8/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/Ax/red-9/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/Ax/red-10/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/Ax/red-1/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/Ax/red-2/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/Ax/red-3/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/Ax/red-4/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/Ax/red-5/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/Ax/red-6/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/Ax/red-7/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/Ax/red-8/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/Ax/red-9/Ax/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/Ax/red-10/Ax/Acts/11(mot,cr)

# %%
#creamos las variables que contienen a la carpeta origen y a la nueva para los datos de pruebas A
#Linux
#ubicacion_original = "/home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/"
#ubicacion_nueva = "/home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/" + "datos_filtrados_pruebas_A"

#Windows--- VERIFICAR RUTA
ubicacion_original = 'C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/'
ubicacion_nueva = 'C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/'+"datos_filtrados_pruebas_A"

if os.path.exists(ubicacion_nueva):
    os.path.exists(ubicacion_original)
else:
    os.mkdir(ubicacion_nueva)

# %%
ruta = ubicacion_original
archivo_nuevo = ubicacion_nueva + '/'
datos_TOTAL = pd.DataFrame()

def sorted_aphanumeric(contenido):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(contenido, key=alphanum_key)

contenido = sorted_aphanumeric(os.listdir(ruta))

for elemento in contenido:
    #Linux
    #archivo_original = ruta + elemento + '/simulation data/A+/'
    #Windows
    archivo_original = ruta + elemento + '/simulacion data/A/'
    print('elemento', archivo_original)
    contenido_entrenamiento = sorted_aphanumeric(os.listdir(archivo_original))
    print(contenido_entrenamiento)
    
    carpeta_nueva = ubicacion_nueva + '/' + elemento
    #creamos la nueva carpeta
    if os.path.exists(carpeta_nueva):
        os.path.exists(ubicacion_original)
    else:
        os.mkdir(carpeta_nueva)
    
    for i in contenido_entrenamiento:
        archivo =  archivo_original + i + '/A/Acts/11(mot,cr)'#VERIFICAR UNIDAD
        print(archivo)
        datos = pd.read_csv(archivo, sep = ': ', engine='python', keep_default_na=False,
                na_values=[' '])
        
        datos_TOTAL = pd.DataFrame(datos)
        datos_TOTAL.columns=[i]
        
        archivo_nuevo = carpeta_nueva + '/' + i
        file = open(archivo_nuevo, "w")
        for valor in datos_TOTAL[i]:
            a = str(valor)
            file.write(a + os.linesep)
    
        file.close()
# Out:
# elemento C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/A/
# ['red-1', 'red-2', 'red-3', 'red-4', 'red-5', 'red-6', 'red-7', 'red-8', 'red-9', 'red-10']
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/A/red-1/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/A/red-2/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/A/red-3/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/A/red-4/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/A/red-5/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/A/red-6/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/A/red-7/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/A/red-8/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/A/red-9/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/A/red-10/A/Acts/11(mot,cr)
# elemento C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/A/
# ['red-1', 'red-2', 'red-3', 'red-4', 'red-5', 'red-6', 'red-7', 'red-8', 'red-9', 'red-10']
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/A/red-1/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/A/red-2/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/A/red-3/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/A/red-4/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/A/red-5/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/A/red-6/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/A/red-7/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/A/red-8/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/A/red-9/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/A/red-10/A/Acts/11(mot,cr)
# elemento C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/A/
# ['red-1', 'red-2', 'red-3', 'red-4', 'red-5', 'red-6', 'red-7', 'red-8', 'red-9', 'red-10']
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/A/red-1/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/A/red-2/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/A/red-3/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/A/red-4/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/A/red-5/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/A/red-6/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/A/red-7/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/A/red-8/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/A/red-9/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/A/red-10/A/Acts/11(mot,cr)
# elemento C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/A/
# ['red-1', 'red-2', 'red-3', 'red-4', 'red-5', 'red-6', 'red-7', 'red-8', 'red-9', 'red-10']
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/A/red-1/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/A/red-2/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/A/red-3/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/A/red-4/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/A/red-5/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/A/red-6/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/A/red-7/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/A/red-8/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/A/red-9/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/A/red-10/A/Acts/11(mot,cr)
# elemento C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/A/
# ['red-1', 'red-2', 'red-3', 'red-4', 'red-5', 'red-6', 'red-7', 'red-8', 'red-9', 'red-10']
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/A/red-1/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/A/red-2/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/A/red-3/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/A/red-4/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/A/red-5/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/A/red-6/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/A/red-7/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/A/red-8/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/A/red-9/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/A/red-10/A/Acts/11(mot,cr)
# elemento C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/A/
# ['red-1', 'red-2', 'red-3', 'red-4', 'red-5', 'red-6', 'red-7', 'red-8', 'red-9', 'red-10']
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/A/red-1/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/A/red-2/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/A/red-3/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/A/red-4/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/A/red-5/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/A/red-6/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/A/red-7/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/A/red-8/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/A/red-9/A/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/A/red-10/A/Acts/11(mot,cr)

# %%
#creamos las variables que contienen a la carpeta origen y a la nueva para los datos de pruebas x
#ubicacion_original = "/home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/A = 1, x = 6, 200 En/"
#ubicacion_nueva = "/home/yan/datos_redes_tesis_doctorado/Con ITI/2-2(2)-2(1)-1 parcialmente/" + "datos_filtrados_pruebas_x"

#Windows--- VERIFICAR RUTA
ubicacion_original = 'C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/'
ubicacion_nueva = 'C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/'+"datos_filtrados_pruebas_x"


if os.path.exists(ubicacion_nueva):
    os.path.exists(ubicacion_original)
else:
    os.mkdir(ubicacion_nueva)

# %%
ruta = ubicacion_original
archivo_nuevo = ubicacion_nueva + '/'
datos_TOTAL = pd.DataFrame()

def sorted_aphanumeric(contenido):
    convert = lambda text: int(text) if text.isdigit() else text.lower()
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(contenido, key=alphanum_key)

contenido = sorted_aphanumeric(os.listdir(ruta))

for elemento in contenido:
    #Linux
    #archivo_original = ruta + elemento + '/simulation data/x-/'
    #Windows
    archivo_original = ruta + elemento + '/simulacion data/x/'
    #print('elemento', archivo_original)
    contenido_entrenamiento = sorted_aphanumeric(os.listdir(archivo_original))
   # print(contenido_entrenamiento)
    
    carpeta_nueva = ubicacion_nueva + '/' + elemento
    #creamos la nueva carpeta
    if os.path.exists(carpeta_nueva):
        os.path.exists(ubicacion_original)
    else:
        os.mkdir(carpeta_nueva)
    
    for i in contenido_entrenamiento:
        archivo =  archivo_original + i + '/x/Acts/11(mot,cr)'#VERIFICAR UNIDAD
        print(archivo)
        datos = pd.read_csv(archivo, sep = ': ', engine='python', keep_default_na=False,
                na_values=[' '])
        
        datos_TOTAL = pd.DataFrame(datos)
        datos_TOTAL.columns=[i]
        
        archivo_nuevo = carpeta_nueva + '/' + i
        file = open(archivo_nuevo, "w")
        for valor in datos_TOTAL[i]:
            a = str(valor)
            file.write(a + os.linesep)
    
        file.close()
# Out:
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/x/red-1/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/x/red-2/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/x/red-3/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/x/red-4/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/x/red-5/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/x/red-6/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/x/red-7/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/x/red-8/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/x/red-9/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A/simulacion data/x/red-10/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/x/red-1/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/x/red-2/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/x/red-3/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/x/red-4/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/x/red-5/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/x/red-6/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/x/red-7/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/x/red-8/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/x/red-9/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(1)x/simulacion data/x/red-10/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/x/red-1/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/x/red-2/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/x/red-3/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/x/red-4/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/x/red-5/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/x/red-6/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/x/red-7/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/x/red-8/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/x/red-9/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(2)x/simulacion data/x/red-10/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/x/red-1/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/x/red-2/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/x/red-3/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/x/red-4/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/x/red-5/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/x/red-6/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/x/red-7/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/x/red-8/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/x/red-9/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/A(4)x/simulacion data/x/red-10/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/x/red-1/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/x/red-2/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/x/red-3/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/x/red-4/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/x/red-5/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/x/red-6/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/x/red-7/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/x/red-8/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/x/red-9/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/Ax/simulacion data/x/red-10/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/x/red-1/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/x/red-2/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/x/red-3/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/x/red-4/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/x/red-5/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/x/red-6/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/x/red-7/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/x/red-8/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/x/red-9/x/Acts/11(mot,cr)
# C:/Users/yanoj/OneDrive/Documentos/simulacion/con ITI/datos/x/simulacion data/x/red-10/x/Acts/11(mot,cr)
